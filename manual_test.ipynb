# %%
from circle import Circle
import matplotlib.pyplot as plt
from rectangle import Rectangle
from plotter import Shape2Dplotter
from cube import Cube
from sphere import Sphere

# %% [markdown]
# test area and perimeter of circle

# %%
c1 = Circle(0,0,1)

print(c1.area)
print(c1.perimeter)
# Out:
# 3.141592653589793
# 6.283185307179586

# %%
# c2 = Circle('one', 2, 3)

# try:
#     print(c2.__repr__)
# except TypeError as err:
#     raise err ('must be a numeric value')

# %% [markdown]
# test area and perimeter of rectangle

# %%
r1 = Rectangle(2, 2, 2, 2)

print(r1.area)
print(r1.perimeter)
# Out:
# 4
# 8

# %% [markdown]
# test eq circle

# %%
c3 = Circle(1, 1, 2)

print(c1==c3)
# Out:
# False

# %% [markdown]
# test eq rectangle and circle

# %%
r2 = Rectangle(2, 2, 2, 2)

print(c1==r2)
print(r2==c1)
# Out:
# False
# False

# %% [markdown]
# test eq rectangle

# %%
r1==r2
# Out:
# True

# %%
r3 = Rectangle(2, 2, 8, 2)

r2==r3
# Out:
# False

# %%
r4 = Rectangle(2,2,4,4)

r3==r4
# Out:
# False

# %% [markdown]
# test less than for circle

# %%
print (c3<c1)
print(c1.area)
print(c3.area)
print(c1<r1)
print(r1.area)
# Out:
# False
# 3.141592653589793
# 12.566370614359172
# True
# 4

# %% [markdown]
# test repr

# %%
c1
# Out:
# Shape(x = 0, y = 0, radius = 1)

# %% [markdown]
# test if circle is unit circle

# %%
c1.is_unit_circle()
# Out:
# True

# %% [markdown]
# tess is square

# %%
r5 = Rectangle(1, 1, 2, 2)

r3.is_square()
# Out:
# False

# %% [markdown]
# test str

# %%
print(r5)
# Out:
# Rectangle with center at (1, 1), width 2, and height 2

# %% [markdown]
# test plotter class

# %%
c7 = Circle(0, 0, 1)
r7 = Rectangle(2,2,2,2)

plotter = Shape2Dplotter()

plotter.add_shape(c7)
plotter.add_shape(r7)
plotter.plot()

# %% [markdown]
# test translate

# %%
c7.translate(3,2)
r7.translate(1,1)

plotter.add_shape(c7)
plotter.add_shape(r7)
plotter.plot()

# %% [markdown]
# test that it still works after i changed code

# %%
c8 = Circle(0, 0, 1)
c8.area
c8.perimeter

c8 == c1
# Out:
# True

# %% [markdown]
# test cube volume

# %%
cube1 = Cube(0, 0, 2)
cube1.volume
# Out:
# 8

# %% [markdown]
# test cube less than

# %%
cube2= Cube(0,0, 3)

cube1 < cube2
# Out:
# True

# %% [markdown]
# test cude surface area

# %%
cube1.surface
# Out:
# 24

# %% [markdown]
# test sphere

# %%
sphere1 = Sphere(0, 0, 1)

print(sphere1)
print(sphere1.volume)
print(sphere1.surface)
# Out:
# Sphere with center at (0, 0), and radius: 1
# 4.1887902047863905
# 12.566370614359172

# %% [markdown]
# from lab 2 instructions to test

# %%
from circle import Circle
from rectangle import Rectangle
circle1 = Circle(x=0, y=0, radius=1)  # unit circle
circle2 = Circle(x=1, y=1, radius=1)
rectangle = Rectangle(x=0, y=0, width=1, height=1)
print(circle1 == circle2)  # True
print(circle2 == rectangle)  # False
circle1.translate(5, 3) # moves its center 5 points in x and 3 points in y
#circle1.translate("THREE", 5)  # raise TypeError with an appropriate message
circle3 = Circle(radius=3) # a circle with center 0,0 with radius 3
circle3 >= circle1 # True
rectangle2 = Rectangle(width=3, height="5") # raise TypeError
# Out:
# True
# False
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 12
#      10 circle3 = Circle(radius=3) # a circle with center 0,0 with radius 3
#      11 circle3 >= circle1 # True
# ---> 12 rectangle2 = Rectangle(width=3, height="5") # raise TypeError
#
# File ~/Desktop/DataEngineer25_GITHUB/lab2_hannah_zemack_de25/rectangle.py:8, in Rectangle.__init__(self, x, y, width, height)
#       6 super().__init__(x, y) #inherit x and y attributes
#       7 if not isinstance(width, (int,float)) or not isinstance(height, (int, float)): #error handling to check id w and h is numbers
# ----> 8     raise TypeError ('height and widht must be a numeric value')
#       9 self._width = width #store width a private attribute
#      10 self._height= height
#
# TypeError: height and widht must be a numeric value
