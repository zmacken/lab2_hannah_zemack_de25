# %% [markdown]
# test area and perimeter of circle

# %%
from circle import Circle
import matplotlib.pyplot as plt

c1 = Circle(0,0,1)

print(c1.area)
print(c1.perimeter)
# Out:
# 3.141592653589793
# 6.283185307179586

# %%
# c2 = Circle('one', 2, 3)

# try:
#     print(c2.__repr__)
# except TypeError as err:
#     raise err ('must be a numeric value')

# %%
from rectangle import Rectangle

r1 = Rectangle(2, 2, 2, 2)

print(r1.area)
print(r1.perimeter)
# Out:
# 4
# 8

# %% [markdown]
# test eq circle

# %%
c3 = Circle(1, 1, 2)

print(c1==c3)
# Out:
# False

# %%
r2 = Rectangle(2, 2, 2, 2)

print(c1==r2)
print(r2==c1)
# Out:
# False
# False

# %%
r1==r2
# Out:
# True

# %%
r3 = Rectangle(2, 2, 8, 2)

r2==r3
# Out:
# False

# %%
r4 = Rectangle(2,2,4,4)

r3==r4
# Out:
# False

# %%
print (c3<c1)
print(c1.area)
print(c3.area)
print(c1<r1)
print(r1.area)
# Out:
# False
# 3.141592653589793
# 12.566370614359172
# True
# 4

# %%
c1
# Out:
# Shape(x = 0, y = 0, radius = 1)

# %%
c1.is_unit_circle()
# Out:
# True

# %%
r5 = Rectangle(1, 1, 2, 2)

r3.is_square()
# Out:
# False

# %%
print(r5)
# Out:
# Rectangle with center at (1, 1), width 2, and height 2

# %%
   # pp1 = plt.Rectangle((0.2, 0.75),
    #                     0.4, 0.15)

    # pp2 = plt.Circle((0.7, 0.2), 0.15)

    # pp3 = plt.Polygon([[0.15, 0.15],
    #                 [0.35, 0.4],
    #                 [0.2, 0.6]])

    # # depict illustrations
    # ax.add_patch(pp1)
    # ax.add_patch(pp2)
    # ax.add_patch(pp3)

pp1 = plt.Rectangle((0.2, 0.75), (0.4, 0.15), 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 15
#       1    # pp1 = plt.Rectangle((0.2, 0.75),
#       2     #                     0.4, 0.15)
#       3
#    (...)     12     # ax.add_patch(pp2)
#      13     # ax.add_patch(pp3)
# ---> 15 pp1 = plt.Rectangle((0.2, 0.75), (0.4, 0.15), 5)
#
# File ~/Desktop/DataEngineer25_GITHUB/lab2_hannah_zemack_de25/.venv/lib/python3.12/site-packages/matplotlib/patches.py:786, in Rectangle.__init__(self, xy, width, height, angle, rotation_point, **kwargs)
#     779 # Required for RectangleSelector with axes aspect ratio != 1
#     780 # The patch is defined in data coordinates and when changing the
#     781 # selector with square modifier and not in data coordinates, we need
#     782 # to correct for the aspect ratio difference between the data and
#     783 # display coordinate systems. Its value is typically provide by
#     784 # Axes._get_aspect_ratio()
#     785 self._aspect_ratio_correction = 1.0
# --> 786 self._convert_units()
#
# File ~/Desktop/DataEngineer25_GITHUB/lab2_hannah_zemack_de25/.venv/lib/python3.12/site-packages/matplotlib/patches.py:796, in Rectangle._convert_units(self)
#     794 x0 = self.convert_xunits(self._x0)
#     795 y0 = self.convert_yunits(self._y0)
# --> 796 x1 = self.convert_xunits(self._x0 + self._width)
#     797 y1 = self.convert_yunits(self._y0 + self._height)
#     798 return x0, y0, x1, y1
#
# TypeError: unsupported operand type(s) for +: 'float' and 'tuple'
