# %% [markdown]
# test area and perimeter of circle

# %%
from circle import Circle

c1 = Circle(1, 1, 1)

print(c1.area)
print(c1.perimeter)
# Out:
# 3.141592653589793
# 6.283185307179586

# %%
# c2 = Circle('one', 2, 3)

# try:
#     print(c2.__repr__)
# except TypeError as err:
#     raise err ('must be a numeric value')

# %%
from rectangle import Rectangle

r1 = Rectangle(2, 2, 2, 2)

print(r1.area)
print(r1.perimeter)
# Out:
# 4
# 8

# %% [markdown]
# test eq circle

# %%
c3 = Circle(1, 1, 1)

print(c1==c3)
# Out:
# True

# %%
r2 = Rectangle(2, 2, 2, 2)

print(c1==r2)
print(r2==c1)
# Out:
# False
# False

# %%
r1==r2
# Out:
# True

# %%
r3 = Rectangle(2, 2, 4, 1)

r2==r3
# Out:
# False

# %%
r4 = Rectangle(2,2,1,4)

r3==r4
# Out:
# True
